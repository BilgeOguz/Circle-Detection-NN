# %% [markdown]
# # CENG428 Neural Networks – Homework 1 & 2
# ## Circle Detection in 2D Point Clouds
#
# **Task:** Given a variable-length set of 2D points, predict:
# 1. **Circle existence** — binary (1 value)
# 2. **Thickness class** — thin / medium / thick (3 softmax scores)
# 3. **Circle parameters** — cx, cy, r (3 values)
#
# **Architecture strategy:**
# - Hand-crafted + learned statistical features from the point set → fixed-size representation
# - Shared MLP backbone + three task heads
# - Multi-task masked loss (thickness & geometry only when circle exists)
# - Data augmentation (rotation, reflection) for regularisation

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import math

torch.manual_seed(42)
np.random.seed(42)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)
print("PyTorch version:", torch.__version__)
# Out:
# Using device: cuda
# PyTorch version: 2.11.0+cu128

# %% [markdown]
# ## 1. Feature Engineering
#
# We extract a **rich fixed-size descriptor** from the variable-length point set that captures the statistical structure a circle produces:
#
# | Group | Features | Rationale |
# |-------|----------|-----------|
# | Basic stats | mean, std, min, max of x and y | global point distribution |
# | Centroid distances | mean, std, skew, kurtosis, min, max | on-circle → very low std of distances |
# | Angular histogram | 16 bins (uniform –π…π) | on-circle → uniform angular spread |
# | Radial histogram | 16 bins (0…√2) | on-circle → sharp peak |
# | PCA | 2 eigenvalues | elongation / circularity |
# | Higher order | 3rd & 4th moments of x,y | shape cues |

# %%
def extract_features(pts: np.ndarray, n_angle_bins=16, n_radial_bins=16) -> np.ndarray:
    """
    Extract a fixed-size feature vector from a variable-length (N,2) point array.
    Returns a 1-D numpy array of length = 8 + n_angle_bins + n_radial_bins + 2 + 4 = 46 by default.
    """
    x, y = pts[:, 0], pts[:, 1]
    feats = []

    # ── 1. Basic coordinate stats (8) ────────────────────────────────────────
    for coord in [x, y]:
        feats += [coord.mean(), coord.std() + 1e-8,
                  coord.min(),  coord.max()]
    # Calculate raw distances BEFORE any scaling/normalization
    raw_dists = np.sqrt(x**2 + y**2)
    
    # Generate the 4 raw thickness features
    raw_std = np.std(raw_dists)
    raw_iqr = np.percentile(raw_dists, 75) - np.percentile(raw_dists, 25)
    raw_mean = np.mean(raw_dists)
    raw_len = float(len(pts))
    raw_thick_feats = np.array([raw_std, raw_iqr, raw_mean, raw_len], dtype=np.float32)

    # ── 2. Centroid-relative distance stats (6) ──────────────────────────────
    cx, cy = x.mean(), y.mean()
    dx, dy = x - cx, y - cy
    dists  = np.sqrt(dx**2 + dy**2)
    d_mean = dists.mean() + 1e-8
    feats += [dists.mean(), dists.std() / (d_mean),         # mean, normalised std
              float(np.mean((dists - dists.mean())**3) / (dists.std()+1e-8)**3),  # skew
              float(np.mean((dists - dists.mean())**4) / (dists.std()+1e-8)**4),  # kurtosis
              dists.min() / (d_mean), dists.max() / (d_mean)]

    # ── 3. Angular histogram (n_angle_bins) ──────────────────────────────────
    angles  = np.arctan2(dy, dx)
    a_hist, _ = np.histogram(angles, bins=n_angle_bins, range=(-np.pi, np.pi))
    a_hist  = a_hist.astype(float)
    a_hist  /= (a_hist.sum() + 1e-8)
    feats   += a_hist.tolist()

    # ── 4. Radial histogram (n_radial_bins) ──────────────────────────────────
    # Removed / (d_mean) to bin raw distances. 
    # Set range to (0, 1.5) assuming your base coordinates are roughly bounded.
    r_hist, _ = np.histogram(dists, bins=n_radial_bins, range=(0, 1.5)) 
    r_hist  = r_hist.astype(float)
    r_hist  /= (r_hist.sum() + 1e-8)
    feats   += r_hist.tolist()

    # ── 5. PCA eigenvalues (2) ───────────────────────────────────────────────
    C = np.cov(np.stack([x, y]))
    eigvals = np.linalg.eigvalsh(C)
    eigvals = np.sort(eigvals)[::-1]
    feats  += (eigvals / (eigvals.sum() + 1e-8)).tolist()

    # ── 6. 3rd & 4th moments of x, y (4) ────────────────────────────────────
    for coord in [x, y]:
        s = coord.std() + 1e-8
        feats += [float(np.mean(((coord - coord.mean())/s)**3)),
                  float(np.mean(((coord - coord.mean())/s)**4))]

    # ── 7. Raw radial spread (3) — key for thickness ─────────────────────────
    feats += [
        float(dists.std()),
        float(dists.std() / d_mean),                                      # normalized spread (≈ thickness/r)
        float((np.percentile(dists, 90) - np.percentile(dists, 10)) / d_mean),  # normalized band width
        float(np.percentile(dists, 75) - np.percentile(dists, 25)),
        float((np.abs(dists - dists.mean()) < 0.2 * d_mean).mean())       # fraction on-circle (keep as-is)
    ]

    return np.array(feats, dtype=np.float32), raw_thick_feats


# Quick sanity check
sample = np.random.randn(100, 2).astype(np.float32)
f = extract_features(sample)
print("Feature vector length:", len(f))
print("Sample feature values:", f[:8])
# Out:
# Feature vector length: 2
# Sample feature values: (array([-0.11556426,  0.85202086, -2.619745  ,  1.8861859 ,  0.03402232,
#         0.99385166, -1.9875689 ,  2.720169  ,  1.1778619 ,  0.4849857 ,
#         0.3853502 ,  2.4732413 ,  0.2363007 ,  2.2840378 ,  0.03      ,
#         0.08      ,  0.07      ,  0.04      ,  0.1       ,  0.08      ,
#         0.03      ,  0.05      ,  0.06      ,  0.05      ,  0.07      ,
#         0.09      ,  0.08      ,  0.04      ,  0.04      ,  0.09      ,
#         0.        ,  0.        ,  0.01470588,  0.0882353 ,  0.07352941,
#         0.02941176,  0.13235295,  0.04411765,  0.10294118,  0.0882353 ,
#         0.04411765,  0.11764706,  0.0882353 ,  0.04411765,  0.04411765,
#         0.0882353 ,  0.5780376 ,  0.42196238, -0.06233505,  3.0148084 ,
#         0.19559827,  2.8133667 ,  0.5712462 ,  0.4849857 ,  1.314211  ,
#         0.88879985,  0.22      ], dtype=float32), array([  0.5692066 ,   0.83418936,   1.1849884 , 100.        ],
#       dtype=float32))

# %% [markdown]
# ## 2. Dataset with Augmentation

# %%
class CircleDataset(Dataset):
    def __init__(self, npz_path, augment=False):
        data = np.load(npz_path, allow_pickle=True)
        self.points  = data['points']    # (N,) of (n_i, 2) arrays
        self.augment = augment
        if 'targets7' in data:
            self.targets = data['targets7']
        else:
            self.targets = None

    def __len__(self):
        return len(self.points)

    def _augment(self, pts, tgt):
        """Random rotation + reflection, keeping targets consistent."""
        # Random rotation
        angle = np.random.uniform(0, 2 * np.pi)
        cos_a, sin_a = np.cos(angle), np.sin(angle)
        R = np.array([[cos_a, -sin_a], [sin_a, cos_a]], dtype=np.float32)
        pts = (R @ pts.T).T

        exists = tgt[0]
        if exists:
            cx, cy, r = tgt[4], tgt[5], tgt[6]
            new_center = R @ np.array([cx, cy], dtype=np.float32)
            tgt = tgt.copy()
            tgt[4], tgt[5] = new_center[0], new_center[1]

        # Random reflection (50 % chance on x-axis)
        if np.random.rand() < 0.5:
            pts[:, 0] = -pts[:, 0]
            if exists:
                tgt = tgt.copy()
                tgt[4] = -tgt[4]

        return pts, tgt

    def __getitem__(self, idx):
        pts = self.points[idx].copy()

        # If we have targets (Training or Validation Phase)
        if self.targets is not None:
            tgt = self.targets[idx].copy()
            
            # 1. Apply augmentations FIRST
            if self.augment:
                pts, tgt = self._augment(pts, tgt)
                
            # 2. Extract features ONCE, after any augmentations are done
            # Unpack both variables to support Fix C!
            feat, raw_thick = extract_features(pts)   
            
            # 3. Return all three tensors
            return (torch.tensor(feat, dtype=torch.float32),
                    torch.tensor(raw_thick, dtype=torch.float32), 
                    torch.tensor(tgt, dtype=torch.float32))
                    
        # If we DO NOT have targets (Testing Phase)
        else:
            # 1. Extract features ONCE
            feat, raw_thick = extract_features(pts)
            
            # 2. Create dummy target
            dummy_tgt = np.zeros(7, dtype=np.float32)
            
            # 3. Return all three tensors
            return (torch.tensor(feat, dtype=torch.float32),
                    torch.tensor(raw_thick, dtype=torch.float32), 
                    torch.tensor(dummy_tgt, dtype=torch.float32))

# Quick check
ds_check = CircleDataset('dataset/train/dataset_all.npz', augment=False)

# ---> THE FIX: Unpack all 3 returned tensors <---
feat0, raw_thick0, tgt0 = ds_check[0] 

print(f"Dataset size: {len(ds_check)}")
print(f"Feature shape: {feat0.shape}")
print(f"Raw Thick shape: {raw_thick0.shape}")
print(f"Target shape: {tgt0.shape}")
print(f"Sample target: {tgt0.numpy()}")
# Out:
# Dataset size: 2000
# Feature shape: torch.Size([57])
# Raw Thick shape: torch.Size([4])
# Target shape: torch.Size([7])
# Sample target: [ 1.          1.          0.          0.          0.1611436  -0.09955481
#   0.46286714]

# %%
# Visualise 8 samples (4 with circles, 4 without)
raw_data = np.load('dataset/train/dataset_all.npz', allow_pickle=True)
all_pts = raw_data['points']
all_tgt = raw_data['targets7']

pos_idx = np.where(all_tgt[:, 0] == 1)[0][:4]
neg_idx = np.where(all_tgt[:, 0] == 0)[0][:4]
idxs    = list(pos_idx) + list(neg_idx)
labels  = ['thin', 'medium', 'thick']

fig, axes = plt.subplots(2, 4, figsize=(16, 8))
for ax, idx in zip(axes.flatten(), idxs):
    pts, tgt = all_pts[idx], all_tgt[idx]
    ax.scatter(pts[:, 0], pts[:, 1], s=4, alpha=0.5)
    if tgt[0] == 1:
        cx, cy, r = tgt[4], tgt[5], tgt[6]
        th = labels[int(tgt[1:4].argmax())]
        circle = plt.Circle((cx, cy), r, fill=False, color='red', lw=2)
        ax.add_patch(circle)
        ax.set_title(f'idx={idx}  {th}  r={r:.2f}', fontsize=9)
    else:
        ax.set_title(f'idx={idx}  no circle', fontsize=9)
    ax.set_xlim(-1.2, 1.2); ax.set_ylim(-1.2, 1.2)
    ax.set_aspect('equal'); ax.axis('off')
plt.suptitle('Sample Visualisation (red = GT circle)', fontsize=13)
plt.tight_layout()
plt.savefig('sample_visualisation.png', dpi=100)
plt.show()
print("Saved: sample_visualisation.png")
# Out:
# Saved: sample_visualisation.png

# %% [markdown]
# ## 3. Model Architecture
#
# ```
# Feature vector (46-d)
#         ↓
#   Shared MLP
#   Linear(46→256) → BN → ReLU → Dropout(0.4)
#   Linear(256→256) → BN → ReLU → Dropout(0.3)
#   Linear(256→128) → BN → ReLU
#         ↓
#   ┌─────────────────┬──────────────────┬──────────────────┐
#   ↓                 ↓                  ↓
# Exist head       Thickness head    Circle params head
# Linear(128→1)    Linear(128→3)     Linear(128→64)→ReLU
# (sigmoid)        (softmax/CE)       →Linear(64→3)
# ```

# %%
class CircleNet(nn.Module):
    def __init__(self, in_dim=55, hidden=256, feat_out=128):
        super().__init__()

        self.backbone = nn.Sequential(
            nn.Linear(in_dim, hidden), nn.BatchNorm1d(hidden), nn.ReLU(), nn.Dropout(0.2),  # was 0.4
            nn.Linear(hidden, hidden), nn.BatchNorm1d(hidden), nn.ReLU(), nn.Dropout(0.2),  # was 0.3
            nn.Linear(hidden, feat_out), nn.BatchNorm1d(feat_out), nn.ReLU(),
        )

        self.head_exist = nn.Linear(feat_out, 1)

        self.thick_encoder = nn.Sequential(
            nn.Linear(4, 32), # Changed input dim to 4
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.Linear(32, 32), 
            nn.ReLU()
        )

        # Takes 128 (backbone) + 32 (raw) = 160
        self.head_thick = nn.Sequential(
            nn.Linear(feat_out + 32, 64), nn.ReLU(), nn.Dropout(0.3),
            nn.Linear(64, 3),
        )

        self.head_circle = nn.Sequential(
            nn.Linear(feat_out, 64), nn.ReLU(), nn.Linear(64, 3),
        )

    def forward(self, feat, raw_thick):
        backbone_feat = self.backbone(feat)
        exist = self.head_exist(backbone_feat)
        
        # Process the 4 raw stats directly
        thick_encoded = self.thick_encoder(raw_thick) 
        
        # Combine detached backbone features with the encoded raw stats
        thick_combined = torch.cat([backbone_feat.detach(), thick_encoded], dim=1) 
        thick = self.head_thick(thick_combined)
        
        circle = self.head_circle(backbone_feat)
        return torch.cat([exist, thick, circle], dim=1)
# Verify
_test_feat = torch.randn(4, 55)       # Main normalized features (adjusted from 46 to 55)
_test_raw_thick = torch.randn(4, 4)   # The 4 raw thickness statistics we added

_net = CircleNet(in_dim=55)           # Make sure in_dim matches your new feature size
_out = _net(_test_feat, _test_raw_thick) # ---> THE FIX: Pass both arguments! <---

assert _out.shape == (4, 7), f"Expected (4,7), got {_out.shape}"
total_params = sum(p.numel() for p in _net.parameters() if p.requires_grad)
print(f"Model parameters: {total_params:,}")
# Out:
# Model parameters: 134,663

# %% [markdown]
# ## 4. Multi-Task Loss
#
# $$\mathcal{L} = w_{exist}\cdot\mathcal{L}_{BCE} + w_{thick}\cdot\mathcal{L}_{CE}^{[e=1]} + w_{circle}\cdot\mathcal{L}_{MSE}^{[e=1]}$$
#
# Thickness and circle losses are **masked** — only applied on samples where the ground-truth circle exists.

# %%
import torch
import torch.nn as nn

class MultiTaskLoss(nn.Module):
    def __init__(self, w_exist=1.0, w_thick=1.0, w_circle=1.0):
        super().__init__()
        self.w_exist = w_exist
        self.w_thick = w_thick
        self.w_circle = w_circle

        # Standard loss functions
        self.criterion_exist = nn.BCEWithLogitsLoss() # For binary existence
        self.criterion_thick = nn.CrossEntropyLoss()  # For 3-class thickness
        self.criterion_circle = nn.MSELoss()          # For x, y, r coordinates

    def forward(self, preds, tgts):
        pred_exist  = preds[:, 0:1]
        pred_thick  = preds[:, 1:4]
        pred_circle = preds[:, 4:7]

        tgt_exist = tgts[:, 0:1].float() 
        
        # ---> THE FIX: Force one-hot to index <---
        # If your dataset has 7 columns [exist, thin, med, thick, x, y, r]
        if tgts.shape[1] == 7:
            tgt_thick = torch.argmax(tgts[:, 1:4], dim=1).long()
            tgt_circle = tgts[:, 4:7].float()
        # If your dataset has 5 columns [exist, thick_idx, x, y, r]
        else:
            tgt_thick = tgts[:, 1].long()    
            tgt_circle = tgts[:, 2:5].float() 
            
        mask = (tgt_exist == 1.0).squeeze(1)
        # ... (keep the rest of your loss logic the same)

        # 3. Calculate Existence Loss (This applies to EVERY sample in the batch)
        loss_exist = self.criterion_exist(pred_exist, tgt_exist)

        # 4. Initialize task losses to 0 (in case a batch randomly has NO circles)
        loss_thick = torch.tensor(0.0, device=preds.device)
        loss_circle = torch.tensor(0.0, device=preds.device)

        # 5. Calculate Thick & Circle Loss ONLY for valid circles
        if mask.sum() > 0: # If at least one circle exists in this batch
            
            # Apply the mask to filter out non-existent circles
            masked_pred_thick = pred_thick[mask]
            masked_tgt_thick = tgt_thick[mask]
            
            masked_pred_circle = pred_circle[mask]
            masked_tgt_circle = tgt_circle[mask]

            # Calculate the loss using ONLY the valid data
            loss_thick = self.criterion_thick(masked_pred_thick, masked_tgt_thick)
            loss_circle = self.criterion_circle(masked_pred_circle, masked_tgt_circle)

        # 6. Combine the losses with their respective weights
        total_loss = (self.w_exist * loss_exist) + \
                     (self.w_thick * loss_thick) + \
                     (self.w_circle * loss_circle)

        return total_loss, (loss_exist.item(), loss_thick.item(), loss_circle.item())

# %% [markdown]
# ## 5. Training Pipeline

# %%
from torch.utils.data import Subset

# ── Hyperparameters ──────────────────────────────────────────────────────────
EPOCHS      = 80
BATCH_SIZE  = 32
LR          = 5e-4
VAL_SPLIT   = 0.2
W_EXIST  = 2.0   # up from 1.0 — give existence more signal
W_THICK  = 3.0
W_CIRCLE = 1.0   # down — MSE values are naturally larger

# ── Datasets ─────────────────────────────────────────────────────────────────
# 1. Initialize the two base datasets first
train_base = CircleDataset('dataset/train/dataset_all.npz', augment=True)
val_base   = CircleDataset('dataset/train/dataset_all.npz', augment=False)

n_val   = int(len(train_base) * VAL_SPLIT)
n_train = len(train_base) - n_val

# Fix the split indices so augmentation is only on train
rng   = torch.Generator().manual_seed(42)
train_idx, val_idx = random_split(range(len(train_base)), [n_train, n_val],
                                  generator=rng)

# 2. Use PyTorch's native Subset to point to the correct base datasets
train_ds = Subset(train_base, train_idx)
val_ds   = Subset(val_base, val_idx)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False)
print(f"Train: {len(train_ds)}  |  Val: {len(val_ds)}")

# ── Model / optimiser / scheduler ────────────────────────────────────────────
sample_feat, sample_raw_thick = extract_features(train_base.points[0])
feat_dim = sample_feat.shape[0]

# 1. Re-initialize the model to apply the new architecture
model = CircleNet(in_dim=feat_dim).to(device) 

criterion = MultiTaskLoss(w_exist=W_EXIST, w_thick=W_THICK, w_circle=W_CIRCLE)

# 3. Re-initialize the optimizer (CRITICAL: Do not skip this)
# If you don't re-create the optimizer, it will crash looking for the old concatenated layers
optimizer = optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-3)

scheduler = optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr=LR, epochs=EPOCHS,
    steps_per_epoch=len(train_loader), pct_start=0.1)

print(f"Feature dim: {feat_dim}")
# Out:
# Train: 1600  |  Val: 400
# Feature dim: 57

# %%
def run_epoch(loader, train=True):
    model.train() if train else model.eval()
    tot = te = tt = tc = 0.0
    n = 0
    ctx = torch.enable_grad() if train else torch.no_grad()
    with ctx:
        # Update unpacking to catch the new raw_thick tensor
        for feat, raw_thick, tgt in loader:
            feat, raw_thick, tgt = feat.to(device), raw_thick.to(device), tgt.to(device)
            
            # Pass both tensors to the model
            preds = model(feat, raw_thick)
            loss, (le, lt, lc) = criterion(preds, tgt)
            if train:
                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                scheduler.step()
            tot += loss.item(); te += le; tt += lt; tc += lc; n += 1
    return tot/n, te/n, tt/n, tc/n


history = {k: [] for k in
           ['train_loss','val_loss',
            'train_exist','val_exist',
            'train_thick','val_thick',
            'train_circle','val_circle']}

best_val_loss = float('inf')
best_state    = None

for epoch in range(1, EPOCHS + 1):
    tl, te, tt, tc = run_epoch(train_loader, train=True)
    vl, ve, vt, vc = run_epoch(val_loader,   train=False)

    for k, v in zip(history.keys(), [tl,vl,te,ve,tt,vt,tc,vc]):
        history[k].append(v)

    if vl < best_val_loss:
        best_val_loss = vl
        best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}

    if epoch % 15 == 0 or epoch == 1:
        print(f"Ep {epoch:3d}/{EPOCHS} | "
              f"Train {tl:.4f} (E:{te:.3f} T:{tt:.3f} C:{tc:.3f}) | "
              f"Val   {vl:.4f} (E:{ve:.3f} T:{vt:.3f} C:{vc:.3f})")

print(f"\nBest val loss: {best_val_loss:.4f}")
model.load_state_dict(best_state)
torch.save(model.state_dict(), 'circle_net_best.pth')
print("Saved: circle_net_best.pth")
# Out:
# Ep   1/80 | Train 4.8593 (E:0.708 T:1.093 C:0.163) | Val   4.7823 (E:0.662 T:1.104 C:0.147)
# Ep  15/80 | Train 4.2936 (E:0.488 T:1.095 C:0.033) | Val   4.1227 (E:0.407 T:1.096 C:0.022)
# Ep  30/80 | Train 4.1782 (E:0.453 T:1.082 C:0.025) | Val   4.0690 (E:0.382 T:1.096 C:0.017)
# Ep  45/80 | Train 4.0659 (E:0.401 T:1.080 C:0.023) | Val   4.0344 (E:0.358 T:1.100 C:0.017)
# Ep  60/80 | Train 4.0775 (E:0.411 T:1.078 C:0.021) | Val   4.0333 (E:0.354 T:1.104 C:0.015)
# Ep  75/80 | Train 4.0594 (E:0.413 T:1.071 C:0.021) | Val   4.0247 (E:0.352 T:1.102 C:0.015)
#
# Best val loss: 4.0220
# Saved: circle_net_best.pth

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for ax, (tk, vk, title) in zip(axes, [
    ('train_loss',   'val_loss',    'Total Loss'),
    ('train_exist',  'val_exist',   'Existence Loss (BCE)'),
    ('train_thick',  'val_thick',   'Thickness Loss (CE)'),
]):
    ax.plot(history[tk], label='Train')
    ax.plot(history[vk], label='Val')
    ax.set_title(title); ax.set_xlabel('Epoch'); ax.legend(); ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=100)
plt.show()
print("Saved: training_curves.png")
# Out:
# Saved: training_curves.png

# %% [markdown]
# ## 6. Validation Performance

# %%
model.eval()

all_ep, all_eg = [], []
all_tp, all_tg = [], []
all_cp, all_cg = [], []

with torch.no_grad():
    # ---> THE FIX: Unpack all 3 tensors <---
    for feat, raw_thick, tgt in val_loader:
        
        # ---> THE FIX: Send raw_thick to the device <---
        feat, raw_thick, tgt = feat.to(device), raw_thick.to(device), tgt.to(device)
        
        # ---> THE FIX: Pass both feature sets to the model <---
        preds = model(feat, raw_thick)

        ep = torch.sigmoid(preds[:, 0])
        tp = preds[:, 1:4].argmax(dim=1)
        cp = preds[:, 4:7]

        all_ep.append(ep.cpu()); all_eg.append(tgt[:, 0].cpu())

        mask = tgt[:, 0].bool()
        if mask.sum():
            all_tp.append(tp[mask].cpu())
            all_tg.append(tgt[mask, 1:4].argmax(dim=1).cpu())
            all_cp.append(cp[mask].cpu())
            all_cg.append(tgt[mask, 4:7].cpu())

exist_pred = torch.cat(all_ep); exist_gt = torch.cat(all_eg)
thick_pred = torch.cat(all_tp); thick_gt = torch.cat(all_tg)
circ_pred  = torch.cat(all_cp); circ_gt  = torch.cat(all_cg)

exist_acc = ((exist_pred >= 0.5).float() == exist_gt).float().mean().item()
thick_acc = (thick_pred == thick_gt).float().mean().item()
mae       = (circ_pred - circ_gt).abs().mean(dim=0)

print("=" * 48)
print("  VALIDATION PERFORMANCE")
print("=" * 48)
print(f"  Existence Accuracy : {exist_acc*100:.2f}%")
print(f"  Thickness Accuracy : {thick_acc*100:.2f}%  (circles only)")
print(f"  MAE cx             : {mae[0]:.4f}")
print(f"  MAE cy             : {mae[1]:.4f}")
print(f"  MAE r              : {mae[2]:.4f}")
print(f"  MAE (mean cx,cy,r) : {mae.mean():.4f}")
print("=" * 48)
# Out:
# ================================================
#   VALIDATION PERFORMANCE
# ================================================
#   Existence Accuracy : 83.25%
#   Thickness Accuracy : 36.40%  (circles only)
#   MAE cx             : 0.1053
#   MAE cy             : 0.1132
#   MAE r              : 0.0564
#   MAE (mean cx,cy,r) : 0.0916
# ================================================

# %%
# Thickness confusion matrix
thickness_names = ['thin', 'medium', 'thick']
conf = np.zeros((3, 3), dtype=int)
for p, g in zip(thick_pred.numpy(), thick_gt.numpy()):
    conf[int(g), int(p)] += 1

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Confusion matrix
ax = axes[0]
im = ax.imshow(conf, cmap='Blues')
ax.set_xticks(range(3)); ax.set_yticks(range(3))
ax.set_xticklabels(thickness_names); ax.set_yticklabels(thickness_names)
ax.set_xlabel('Predicted'); ax.set_ylabel('True')
ax.set_title('Thickness Confusion Matrix (val, circles only)')
for i in range(3):
    for j in range(3):
        ax.text(j, i, conf[i,j], ha='center', va='center',
                color='white' if conf[i,j]>conf.max()*0.6 else 'black', fontsize=12)
plt.colorbar(im, ax=ax)

# Circle parameter error scatter
ax = axes[1]
for dim, label, color in zip(range(3), ['cx','cy','r'], ['#e74c3c','#2ecc71','#3498db']):
    err = (circ_pred[:, dim] - circ_gt[:, dim]).abs().numpy()
    ax.hist(err, bins=20, alpha=0.6, label=label, color=color)
ax.set_xlabel('Absolute Error'); ax.set_ylabel('Count')
ax.set_title('Circle Parameter MAE Distribution (val)'); ax.legend()

plt.tight_layout()
plt.savefig('val_metrics.png', dpi=100)
plt.show()
print("Saved: val_metrics.png")
# Out:
# Saved: val_metrics.png

# %% [markdown]
# ## 7. Testing Phase
#
# Load the separate test `.npz` files and run inference. This is exactly how the grading test set will be evaluated.

# %%
def load_test_samples(npz_paths):
    """Load test samples from a list of .npz file paths."""
    samples = []
    for path in npz_paths:
        d   = np.load(path, allow_pickle=True)
        pts = d['points']                        # (n, 2) numpy
        samples.append(pts)
    return samples


def predict_samples(model, samples):
    results = []
    thickness_names = ['thin', 'medium', 'thick']
    
    for pts in samples:
        feat, raw_thick = extract_features(pts)
        
        feat_t = torch.tensor(feat, dtype=torch.float32).unsqueeze(0).to(device)
        raw_thick_t = torch.tensor(raw_thick, dtype=torch.float32).unsqueeze(0).to(device)
        
        with torch.no_grad():
            pred = model(feat_t, raw_thick_t)[0]    # (7,)
            
        e_prob = torch.sigmoid(pred[0]).item()
        e      = (e_prob >= 0.5)
        
        if e:
            th_idx = pred[1:4].argmax().item()
            th     = thickness_names[th_idx]
            cx, cy, r = pred[4:7].cpu().numpy()
        else:
            th = "–"
            cx, cy, r = 0.0, 0.0, 0.0
            
        # ---> THE FIX: Construct the specific 7-column array your save script expects <---
        target7 = np.array([
            e_prob,                  # 1. exists_prob
            pred[1].item(),          # 2. thin_score
            pred[2].item(),          # 3. med_score
            pred[3].item(),          # 4. thick_score
            cx,                      # 5. cx
            cy,                      # 6. cy
            r                        # 7. r
        ], dtype=np.float32)
            
        results.append({
            'exists': e,
            'exists_prob': e_prob,
            'thickness_name': th,
            'cx': cx,
            'cy': cy,
            'r': r,
            'target7': target7       # ---> THE FIX: Add it to the dictionary <---
        })
        
    return results

# %%
import glob, os

test_files  = sorted(glob.glob('dataset/test/sample_*.npz'))
print(f"Found {len(test_files)} test files.")

if not test_files:
    print("No sample_*.npz files found. Adjust the glob pattern to point at your test data.")
else:
    test_samples = load_test_samples(test_files)
    predictions  = predict_samples(model, test_samples)

    # ── Formatted results ─────────────────────────────────────────────────────
    print(f"\n{'File':<22} {'Exists':>7} {'Prob':>6} {'Thickness':>10} {'cx':>7} {'cy':>7} {'r':>7}")
    print("-" * 70)
    for fname, pred in zip(test_files, predictions):
        e  = pred['exists']
        pr = f"{pred['exists_prob']:.3f}"
        th = pred['thickness_name'] if e else '–'
        cx = f"{pred['cx']:.3f}"   if e else '–'
        cy = f"{pred['cy']:.3f}"   if e else '–'
        r  = f"{pred['r']:.3f}"    if e else '–'
        print(f"{os.path.basename(fname):<22} {e:>7} {pr:>6} {th:>10} {cx:>7} {cy:>7} {r:>7}")
# Out:
# Found 400 test files.
#
# File                    Exists   Prob  Thickness      cx      cy       r
# ----------------------------------------------------------------------
# sample_00000.npz             0  0.234          –       –       –       –
# sample_00001.npz             1  0.964     medium  -0.233   0.033   0.449
# sample_00002.npz             1  0.822      thick  -0.163   0.284   0.521
# sample_00003.npz             1  0.916     medium   0.319   0.082   0.382
# sample_00004.npz             1  0.644     medium   0.290   0.267   0.274
# sample_00378.npz             1  0.787     medium  -0.030   0.155   0.383
# sample_00379.npz             1  0.870      thick  -0.015   0.327   0.482
# sample_00380.npz             1  0.933       thin   0.459   0.373   0.216
# sample_00381.npz             0  0.226          –       –       –       –
# sample_00382.npz             0  0.005          –       –       –       –
# sample_00383.npz             1  0.915      thick  -0.444  -0.506   0.233
# sample_00384.npz             0  0.477          –       –       –       –
# sample_00385.npz             0  0.237          –       –       –       –
# sample_00386.npz             0  0.010          –       –       –       –
# sample_00387.npz             0  0.025          –       –       –       –
# sample_00388.npz             1  0.771      thick  -0.258  -0.365   0.350
# sample_00389.npz             1  0.867     medium  -0.425  -0.277   0.282
# sample_00390.npz             0  0.017          –       –       –       –
# sample_00391.npz             0  0.365          –       –       –       –
# sample_00392.npz             1  0.907      thick  -0.295  -0.321   0.341
# sample_00393.npz             1  0.960      thick   0.162  -0.139   0.475
# sample_00394.npz             1  0.732      thick   0.039  -0.181   0.401
# sample_00395.npz             1  0.617      thick   0.144   0.393   0.403
# sample_00396.npz             1  0.969       thin   0.312   0.193   0.305
# sample_00397.npz             1  0.629       thin  -0.027  -0.555   0.387
# sample_00398.npz             1  0.939     medium  -0.277   0.506   0.326
# sample_00399.npz             1  0.796     medium  -0.119   0.189   0.388

# %%
# ── Compare with ground truth ─────────────────────────────────────────────────
print("\nGround truth comparison:")
print(f"{'File':<20} {'GT_E':>5} {'PR_E':>5} {'GT_Th':>8} {'PR_Th':>8} {'GT_cx':>7} {'PR_cx':>7} {'GT_r':>6} {'PR_r':>6}")
print("-" * 78)
thickness_names = ['thin','medium','thick']

for fname, pred in zip(test_files, predictions):
    d   = np.load(fname, allow_pickle=True)
    gt  = d['target7']
    gt_e  = int(gt[0])
    gt_th = thickness_names[int(gt[1:4].argmax())] if gt_e else '–'
    gt_cx = f"{gt[4]:.3f}" if gt_e else '–'
    gt_r  = f"{gt[6]:.3f}" if gt_e else '–'
    pr_e  = pred['exists']
    pr_th = pred['thickness_name'] if pr_e else '–'
    pr_cx = f"{pred['cx']:.3f}" if pr_e else '–'
    pr_r  = f"{pred['r']:.3f}"  if pr_e else '–'
    ok    = '✓' if gt_e == pr_e else '✗'
    print(f"{os.path.basename(fname):<20} {gt_e:>5} {pr_e:>4}{ok}"
          f" {gt_th:>8} {pr_th:>8} {gt_cx:>7} {pr_cx:>7} {gt_r:>6} {pr_r:>6}")
# Out:
# Ground truth comparison:
# File                  GT_E  PR_E    GT_Th    PR_Th   GT_cx   PR_cx   GT_r   PR_r
# ------------------------------------------------------------------------------
# sample_00000.npz         0    0✓        –        –       –       –      –      –
# sample_00001.npz         1    1✓     thin   medium  -0.256  -0.233  0.505  0.449
# sample_00002.npz         0    1✗        –    thick       –  -0.163      –  0.521
# sample_00003.npz         1    1✓     thin   medium   0.420   0.319  0.369  0.382
# sample_00004.npz         0    1✗        –   medium       –   0.290      –  0.274
# sample_00005.npz         0    1✗        –     thin       –   0.393      –  0.262
# sample_00006.npz         1    1✓     thin   medium  -0.543  -0.585  0.206  0.257
# sample_00007.npz         1    1✓    thick   medium   0.228   0.166  0.460  0.399
# sample_00142.npz         1    1✓     thin     thin  -0.045  -0.036  0.205  0.270
# sample_00143.npz         1    1✓     thin     thin   0.262   0.260  0.394  0.380
# sample_00144.npz         1    1✓     thin   medium  -0.513  -0.357  0.330  0.240
# sample_00145.npz         1    1✓   medium     thin   0.472   0.402  0.231  0.230
# sample_00146.npz         0    0✓        –        –       –       –      –      –
# sample_00147.npz         0    0✓        –        –       –       –      –      –
# sample_00148.npz         1    1✓    thick   medium   0.074   0.153  0.550  0.494
# sample_00149.npz         1    0✗     thin        –   0.433       –  0.164      –
# sample_00150.npz         1    1✓    thick     thin   0.617   0.578  0.275  0.228
# sample_00151.npz         0    0✓        –        –       –       –      –      –
# sample_00152.npz         1    1✓    thick   medium   0.050  -0.070  0.400  0.490
# sample_00153.npz         0    0✓        –        –       –       –      –      –
# sample_00154.npz         1    1✓     thin     thin   0.512   0.485  0.239  0.290
# sample_00155.npz         1    0✗   medium        –  -0.025       –  0.361      –
# sample_00156.npz         1    1✓     thin   medium   0.240   0.198  0.289  0.267
# sample_00157.npz         1    1✓    thick    thick  -0.400  -0.276  0.382  0.379
# sample_00158.npz         1    1✓    thick     thin  -0.448  -0.319  0.430  0.366
# sample_00159.npz         1    1✓    thick     thin   0.068   0.008  0.282  0.302
# sample_00160.npz         1    1✓   medium   medium   0.039  -0.083  0.325  0.342
# sample_00161.npz         1    1✓    thick   medium  -0.049  -0.036  0.399  0.435
# sample_00162.npz         1    1✓     thin     thin  -0.477  -0.394  0.152  0.205
# sample_00163.npz         1    1✓   medium     thin   0.477   0.409  0.138  0.206
# sample_00164.npz         1    1✓   medium    thick   0.140   0.100  0.499  0.509
# sample_00165.npz         0    0✓        –        –       –       –      –      –
# sample_00166.npz         1    0✗    thick        –  -0.329       –  0.262      –
# sample_00167.npz         0    0✓        –        –       –       –      –      –
# sample_00168.npz         0    0✓        –        –       –       –      –      –
# sample_00169.npz         0    0✓        –        –       –       –      –      –
# sample_00170.npz         0    1✗        –   medium       –  -0.152      –  0.499
# sample_00171.npz         1    1✓   medium    thick   0.129   0.161  0.381  0.377
# sample_00172.npz         0    0✓        –        –       –       –      –      –
# sample_00173.npz         1    1✓     thin     thin  -0.218  -0.313  0.298  0.318
# sample_00174.npz         1    1✓     thin   medium   0.211   0.089  0.446  0.498
# sample_00175.npz         0    0✓        –        –       –       –      –      –
# sample_00176.npz         0    0✓        –        –       –       –      –      –
# sample_00177.npz         1    1✓    thick   medium   0.107  -0.069  0.343  0.395
# sample_00178.npz         1    1✓   medium   medium   0.337   0.205  0.475  0.462
# sample_00179.npz         1    1✓     thin   medium  -0.188  -0.138  0.521  0.509
# sample_00180.npz         1    1✓    thick     thin   0.605   0.421  0.276  0.206
# sample_00181.npz         0    0✓        –        –       –       –      –      –
# sample_00182.npz         0    0✓        –        –       –       –      –      –
# sample_00183.npz         1    1✓   medium   medium  -0.242  -0.309  0.353  0.350
# sample_00184.npz         1    1✓   medium    thick   0.107  -0.186  0.436  0.421
# sample_00185.npz         0    0✓        –        –       –       –      –      –
# sample_00272.npz         1    1✓     thin   medium  -0.130  -0.219  0.305  0.338
# sample_00273.npz         0    0✓        –        –       –       –      –      –
# sample_00274.npz         0    0✓        –        –       –       –      –      –
# sample_00275.npz         0    0✓        –        –       –       –      –      –
# sample_00276.npz         1    1✓   medium     thin  -0.459  -0.413  0.217  0.227
# sample_00277.npz         1    1✓   medium   medium  -0.618  -0.590  0.181  0.234
# sample_00278.npz         0    1✗        –   medium       –   0.056      –  0.343
# sample_00279.npz         0    0✓        –        –       –       –      –      –
# sample_00280.npz         1    1✓     thin     thin  -0.575  -0.424  0.248  0.214
# sample_00281.npz         1    0✗     thin        –   0.038       –  0.405      –
# sample_00282.npz         1    1✓     thin    thick  -0.249  -0.443  0.212  0.214
# sample_00283.npz         1    1✓     thin     thin  -0.135  -0.136  0.277  0.296
# sample_00284.npz         1    1✓     thin   medium   0.335   0.395  0.304  0.293
# sample_00285.npz         1    0✗   medium        –  -0.677       –  0.196      –
# sample_00286.npz         0    0✓        –        –       –       –      –      –
# sample_00287.npz         1    1✓   medium    thick  -0.329  -0.309  0.380  0.291
# sample_00288.npz         1    0✗    thick        –   0.077       –  0.216      –
# sample_00289.npz         0    0✓        –        –       –       –      –      –
# sample_00290.npz         1    1✓    thick     thin  -0.363  -0.363  0.220  0.234
# sample_00291.npz         0    0✓        –        –       –       –      –      –
# sample_00292.npz         0    0✓        –        –       –       –      –      –
# sample_00293.npz         1    0✗    thick        –  -0.183       –  0.327      –
# sample_00294.npz         1    0✗   medium        –   0.359       –  0.459      –
# sample_00295.npz         0    0✓        –        –       –       –      –      –
# sample_00296.npz         1    1✓   medium   medium   0.411   0.400  0.365  0.281
# sample_00297.npz         1    1✓   medium    thick  -0.473  -0.327  0.345  0.289
# sample_00298.npz         0    0✓        –        –       –       –      –      –
# sample_00299.npz         1    1✓    thick   medium  -0.311  -0.258  0.464  0.435
# sample_00300.npz         0    0✓        –        –       –       –      –      –
# sample_00301.npz         0    1✗        –     thin       –  -0.361      –  0.353
# sample_00302.npz         1    1✓   medium     thin   0.582   0.490  0.156  0.169
# sample_00303.npz         0    1✗        –    thick       –   0.452      –  0.201
# sample_00304.npz         0    0✓        –        –       –       –      –      –
# sample_00305.npz         0    1✗        –     thin       –  -0.509      –  0.208
# sample_00306.npz         0    0✓        –        –       –       –      –      –
# sample_00307.npz         1    0✗     thin        –  -0.275       –  0.346      –
# sample_00308.npz         1    1✓   medium   medium   0.198   0.003  0.508  0.520
# sample_00309.npz         0    1✗        –     thin       –  -0.480      –  0.333
# sample_00310.npz         1    1✓    thick     thin   0.024  -0.234  0.300  0.303
# sample_00311.npz         1    1✓    thick     thin  -0.300  -0.370  0.259  0.295
# sample_00312.npz         1    1✓   medium   medium   0.300   0.223  0.134  0.257
# sample_00313.npz         1    1✓   medium   medium   0.351   0.286  0.154  0.163
# sample_00314.npz         1    0✗    thick        –  -0.155       –  0.125      –
# sample_00315.npz         1    1✓     thin    thick  -0.197  -0.221  0.456  0.339
# sample_00316.npz         1    1✓     thin    thick   0.450   0.329  0.265  0.317
# sample_00317.npz         1    1✓     thin    thick   0.244   0.271  0.347  0.331
# sample_00318.npz         0    0✓        –        –       –       –      –      –
# sample_00319.npz         0    0✓        –        –       –       –      –      –
# sample_00320.npz         1    1✓    thick    thick  -0.670  -0.528  0.207  0.255
# sample_00321.npz         0    0✓        –        –       –       –      –      –
# sample_00322.npz         0    0✓        –        –       –       –      –      –
# sample_00323.npz         1    1✓    thick     thin   0.309   0.319  0.296  0.280
# sample_00324.npz         1    1✓     thin    thick  -0.191  -0.118  0.547  0.369
# sample_00325.npz         1    0✗   medium        –   0.435       –  0.464      –
# sample_00326.npz         0    0✓        –        –       –       –      –      –
# sample_00327.npz         0    0✓        –        –       –       –      –      –
# sample_00328.npz         1    1✓   medium    thick  -0.016  -0.082  0.549  0.503
# sample_00329.npz         1    1✓     thin    thick  -0.309  -0.359  0.273  0.208
# sample_00330.npz         1    0✗     thin        –  -0.254       –  0.543      –
# sample_00331.npz         1    1✓    thick     thin   0.521   0.416  0.145  0.215
# sample_00332.npz         1    0✗    thick        –   0.672       –  0.222      –
# sample_00333.npz         0    0✓        –        –       –       –      –      –
# sample_00334.npz         0    0✓        –        –       –       –      –      –
# sample_00335.npz         1    1✓   medium    thick  -0.287  -0.426  0.151  0.118
# sample_00336.npz         1    1✓   medium     thin   0.366   0.172  0.495  0.469
# sample_00337.npz         1    1✓   medium    thick  -0.509  -0.278  0.397  0.301
# sample_00338.npz         0    0✓        –        –       –       –      –      –
# sample_00339.npz         1    1✓     thin    thick   0.042  -0.044  0.536  0.427
# sample_00340.npz         1    0✗    thick        –  -0.036       –  0.173      –
# sample_00341.npz         0    1✗        –   medium       –  -0.483      –  0.273
# sample_00342.npz         1    1✓   medium    thick  -0.044  -0.110  0.211  0.286
# sample_00343.npz         1    1✓    thick     thin   0.199   0.228  0.345  0.331
# sample_00344.npz         1    1✓   medium     thin   0.505   0.593  0.265  0.236
# sample_00345.npz         1    1✓     thin    thick  -0.051  -0.198  0.259  0.410
# sample_00346.npz         0    0✓        –        –       –       –      –      –
# sample_00347.npz         1    1✓     thin     thin   0.151   0.052  0.181  0.236
# sample_00348.npz         1    1✓     thin    thick  -0.184  -0.145  0.120  0.218
# sample_00349.npz         0    0✓        –        –       –       –      –      –
# sample_00350.npz         0    1✗        –   medium       –  -0.289      –  0.275
# sample_00351.npz         1    1✓   medium   medium  -0.163   0.150  0.387  0.430
# sample_00352.npz         1    1✓   medium    thick   0.146   0.152  0.487  0.457
# sample_00353.npz         1    1✓    thick   medium  -0.198  -0.237  0.139  0.145
# sample_00354.npz         0    0✓        –        –       –       –      –      –
# sample_00355.npz         1    1✓    thick    thick   0.269   0.475  0.548  0.349
# sample_00356.npz         1    1✓    thick   medium  -0.474  -0.287  0.330  0.373
# sample_00357.npz         1    1✓    thick   medium   0.215   0.099  0.530  0.504
# sample_00358.npz         0    0✓        –        –       –       –      –      –
# sample_00359.npz         1    0✗     thin        –   0.345       –  0.266      –
# sample_00360.npz         1    1✓    thick   medium  -0.021  -0.317  0.466  0.286
# sample_00361.npz         1    1✓   medium     thin   0.710   0.590  0.184  0.213
# sample_00362.npz         0    1✗        –    thick       –  -0.202      –  0.304
# sample_00363.npz         1    1✓     thin   medium  -0.250  -0.214  0.202  0.133
# sample_00364.npz         0    1✗        –    thick       –  -0.129      –  0.343
# sample_00365.npz         1    1✓     thin    thick  -0.417  -0.267  0.424  0.339
# sample_00366.npz         0    1✗        –     thin       –   0.189      –  0.251
# sample_00367.npz         1    1✓   medium    thick  -0.044  -0.249  0.425  0.308
# sample_00368.npz         0    0✓        –        –       –       –      –      –
# sample_00369.npz         1    1✓    thick    thick  -0.373  -0.201  0.324  0.380
# sample_00370.npz         1    1✓   medium     thin   0.386   0.335  0.196  0.196
# sample_00371.npz         1    1✓    thick   medium  -0.245  -0.121  0.537  0.493
# sample_00372.npz         1    0✗     thin        –  -0.005       –  0.135      –
# sample_00373.npz         1    1✓   medium    thick  -0.019   0.207  0.492  0.347
# sample_00374.npz         0    0✓        –        –       –       –      –      –
# sample_00375.npz         1    0✗   medium        –   0.678       –  0.149      –
# sample_00376.npz         1    0✗    thick        –  -0.122       –  0.342      –
# sample_00377.npz         0    1✗        –   medium       –   0.385      –  0.325
# sample_00378.npz         0    1✗        –   medium       –  -0.030      –  0.383
# sample_00379.npz         1    1✓    thick    thick   0.248  -0.015  0.515  0.482
# sample_00380.npz         1    1✓    thick     thin   0.486   0.459  0.120  0.216
# sample_00381.npz         0    0✓        –        –       –       –      –      –
# sample_00382.npz         0    0✓        –        –       –       –      –      –
# sample_00383.npz         1    1✓   medium    thick  -0.600  -0.444  0.140  0.233
# sample_00384.npz         0    0✓        –        –       –       –      –      –
# sample_00385.npz         1    0✗   medium        –  -0.200       –  0.170      –
# sample_00386.npz         0    0✓        –        –       –       –      –      –
# sample_00387.npz         0    0✓        –        –       –       –      –      –
# sample_00388.npz         1    1✓     thin    thick  -0.168  -0.258  0.356  0.350
# sample_00389.npz         1    1✓   medium   medium  -0.483  -0.425  0.371  0.282
# sample_00390.npz         0    0✓        –        –       –       –      –      –
# sample_00391.npz         1    0✗   medium        –  -0.097       –  0.303      –
# sample_00392.npz         1    1✓     thin    thick  -0.458  -0.295  0.334  0.341
# sample_00393.npz         1    1✓    thick    thick   0.136   0.162  0.529  0.475
# sample_00394.npz         1    1✓   medium    thick   0.354   0.039  0.414  0.401
# sample_00395.npz         1    1✓    thick    thick   0.346   0.144  0.462  0.403
# sample_00396.npz         1    1✓     thin     thin   0.454   0.312  0.323  0.305
# sample_00397.npz         0    1✗        –     thin       –  -0.027      –  0.387
# sample_00398.npz         1    1✓   medium   medium  -0.441  -0.277  0.248  0.326
# sample_00399.npz         0    1✗        –   medium       –  -0.119      –  0.388

# %%
# ── Save predictions ──────────────────────────────────────────────────────────
if test_files:
    pred_array = np.array([p['target7'] for p in predictions], dtype=np.float32)
    np.savez('test_predictions.npz',
             predictions=pred_array,
             files=np.array(test_files))
    print(f"\nSaved → test_predictions.npz  shape={pred_array.shape}")
    print("Columns: [exists_prob, thin_score, med_score, thick_score, cx, cy, r]")
# Out:
# Saved → test_predictions.npz  shape=(400, 7)
# Columns: [exists_prob, thin_score, med_score, thick_score, cx, cy, r]
